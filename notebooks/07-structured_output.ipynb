# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
llm = init_chat_model("openai:gpt-4o",temperature=0)
response = llm.invoke("Hola soy Saúl, mi telefono es 1234567890")
response.text
# Out:
# 'Hola, Saúl. Lamentablemente, no puedo procesar ni almacenar información personal como números de teléfono. Si tienes alguna pregunta o necesitas ayuda con algo, estaré encantado de asistirte.'

# %%
from pydantic import BaseModel, Field
class ContactInfo(BaseModel):
    """Contact information for a person"""
    name: str = Field(description="The name of the person")
    email: str = Field(description="The email of the address of the person")
    phone: str = Field(description="The phone number of the person")
    tone: int = Field(description="The tone of the person", ge=0, le=100)
    age: int = Field(description="The age of the person")
    sentiment: str = Field(description="The sentiment conversation of the person")
    
llm_with_structured_output = llm.with_structured_output(schema=ContactInfo)
messages = [
    "system", "You are a helpful assistant that can extract information from a conversation.",
    "user", "Hola soy Saúl, mi telefono es 1234567890"
]

response = llm_with_structured_output.invoke(messages)
response.name
# Out:
# /home/sunde/projects/Platzi/LangGraph/course/my_course_agent/.venv/lib/python3.12/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='parsed', input_value=ContactInfo(name='Saúl',...=0, sentiment='neutral'), input_type=ContactInfo])
#   return self.__pydantic_serializer__.to_python(
# 'Saúl'

# %%
response.phone
# Out:
# '1234567890'
