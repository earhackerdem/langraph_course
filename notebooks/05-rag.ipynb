# %%
from langchain.chat_models import init_chat_model
llm = init_chat_model("openai:gpt-4o",temperature=0)

# %%
file_search_tool = {
    "type": "file_search",
    "vector_store_ids" : ['vs_69af0b45173081918ccbab0b48bc49fe']
}

llm_with_tools = llm.bind_tools([file_search_tool])

# %%
response = llm_with_tools.invoke("Como mejoro el rendimiento de mi website?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'id': 'fs_0166c90f9ef5e42f0069af186987548197b91076472c11b1e9', 'queries': ['Como mejoro el rendimiento de mi website?'], 'status': 'completed', 'type': 'file_search_call'}, {'type': 'text', 'text': 'Para mejorar el rendimiento de tu sitio web, puedes seguir estas recomendaciones:\n\n1. **Optimización de Imágenes**: Asegúrate de que las imágenes estén correctamente dimensionadas y utiliza formatos de próxima generación como WebP para reducir el tiempo de carga.\n\n2. **Eliminar Recursos que Bloquean el Renderizado**: Minimiza el uso de scripts y estilos que bloquean el renderizado para mejorar la velocidad de carga.\n\n3. **Minificar JavaScript y CSS**: Reduce el tamaño de los archivos JavaScript y CSS eliminando espacios en blanco y comentarios innecesarios.\n\n4. **Habilitar la Compresión de Texto**: Utiliza la compresión Gzip para reducir el tamaño de los archivos enviados desde el servidor.\n\n5. **Implementar AMP (Accelerated Mobile Pages)**: Considera usar AMP para crear páginas que se carguen casi instantáneamente.\n\n6. **Establecer Presupuestos de Rendimiento**: Define límites en métricas clave de rendimiento para asegurarte de que tu sitio se mantenga rápido.\n\n7. **Utilizar Herramientas de Análisis**: Herramientas como Lighthouse y WebPageTest pueden ayudarte a identificar áreas de mejora y medir el rendimiento de tu sitio.\n\nImplementar estas prácticas puede ayudarte a mejorar significativamente la velocidad y el rendimiento de tu sitio web.', 'annotations': [{'file_id': 'file-3Ts7Ni72mNyUAET2MZ3H25', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 262}, {'file_id': 'file-3Ts7Ni72mNyUAET2MZ3H25', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 418}, {'file_id': 'file-3Ts7Ni72mNyUAET2MZ3H25', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 562}, {'file_id': 'file-3Ts7Ni72mNyUAET2MZ3H25', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 698}, {'file_id': 'file-3Ts7Ni72mNyUAET2MZ3H25', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 826}, {'file_id': 'file-3Ts7Ni72mNyUAET2MZ3H25', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 974}, {'file_id': 'file-3Ts7Ni72mNyUAET2MZ3H25', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 1142}], 'id': 'msg_0166c90f9ef5e42f0069af186b91508197bc2e9d3729a583c0'}]

# %%
response = llm.invoke("Como mejoro el rendimiento de mi website?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Mejorar el rendimiento de un sitio web es crucial para ofrecer una buena experiencia de usuario y optimizar el SEO. Aquí tienes algunas estrategias que puedes implementar:
#
# 1. **Optimización de Imágenes**: Asegúrate de que las imágenes estén en el formato adecuado (como WebP) y comprimidas para reducir su tamaño sin perder calidad. Utiliza herramientas como TinyPNG o ImageOptim.
#
# 2. **Uso de CDN (Content Delivery Network)**: Un CDN distribuye el contenido de tu sitio web a través de múltiples servidores en todo el mundo, reduciendo el tiempo de carga para los usuarios que están lejos del servidor principal.
#
# 3. **Minificación de Archivos**: Reduce el tamaño de los archivos CSS, JavaScript y HTML eliminando espacios, comentarios y líneas innecesarias. Herramientas como UglifyJS y CSSNano pueden ayudarte.
#
# 4. **Habilitar la Compresión**: Activa la compresión Gzip en tu servidor para reducir el tamaño de los archivos enviados al navegador.
#
# 5. **Caché del Navegador**: Configura el caché del navegador para que los elementos estáticos de tu sitio se almacenen localmente en el dispositivo del usuario, reduciendo el tiempo de carga en visitas posteriores.
#
# 6. **Optimización del Código**: Revisa y optimiza el código de tu sitio para asegurarte de que no haya scripts o estilos innecesarios que puedan ralentizar la carga.
#
# 7. **Carga Diferida (Lazy Loading)**: Implementa la carga diferida para imágenes y vídeos, de modo que solo se carguen cuando estén a punto de entrar en el campo de visión del usuario.
#
# 8. **Revisar Plugins y Scripts**: Desactiva o elimina plugins y scripts innecesarios, especialmente en plataformas como WordPress, donde los plugins pueden afectar significativamente el rendimiento.
#
# 9. **Mejorar el Tiempo de Respuesta del Servidor**: Asegúrate de que tu servidor esté optimizado y considera actualizar a un hosting más rápido si es necesario.
#
# 10. **Uso de AMP (Accelerated Mobile Pages)**: Implementa AMP para mejorar la velocidad de carga en dispositivos móviles.
#
# 11. **Monitoreo y Pruebas**: Utiliza herramientas como Google PageSpeed Insights, GTmetrix o Pingdom para analizar el rendimiento de tu sitio y obtener recomendaciones específicas.
#
# Implementar estas estrategias puede ayudar a mejorar significativamente el rendimiento de tu sitio web, ofreciendo una mejor experiencia a tus usuarios y mejorando tu posicionamiento en los motores de búsqueda.

# %%
response = llm_with_tools.invoke("Hola como estas?")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'type': 'text', 'text': '¡Hola! Estoy bien, gracias. ¿En qué puedo ayudarte hoy con los archivos que has subido?', 'annotations': [], 'id': 'msg_0c5c7675da6b64930069af194637a08192bb93b9e8bd43201d'}]
